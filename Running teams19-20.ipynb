# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %matplotlib inline

# %%
data = pd.read_csv('./data/season19-20.csv')
#data = pd.read_csv('./data/season18-19.csv')
#data = pd.read_csv('./data/season17-18.csv')

# %%
data.head()
# Out:
#   Div        Date   Time        HomeTeam          AwayTeam  FTHG  FTAG FTR  \
# 0  E0  08/09/2019  20:00       Liverpool           Norwich     4     1   H
# 1  E0  08/10/2019  12:30        West Ham          Man City     0     5   A
# 2  E0  08/10/2019  15:00     Bournemouth  Sheffield United     1     1   D
# 3  E0  08/10/2019  15:00         Burnley       Southampton     3     0   H
# 4  E0  08/10/2019  15:00  Crystal Palace           Everton     0     0   D
#
#    HTHG  HTAG  ... AvgC<2.5  AHCh  B365CAHH  B365CAHA  PCAHH  PCAHA  MaxCAHH  \
# 0     4     0  ...     3.43 -2.25      1.91      1.99   1.94   1.98     1.99
# 1     0     1  ...     2.91  1.75      1.95      1.95   1.96   1.97     2.07
# 2     0     0  ...     1.92 -0.50      1.95      1.95   1.98   1.95     2.00
# 3     0     0  ...     1.71  0.00      1.87      2.03   1.89   2.03     1.90
# 4     0     0  ...     1.71  0.25      1.82      2.08   1.97   1.96     2.03
#
#    MaxCAHA  AvgCAHH  AvgCAHA
# ...

# %%
# I need the data to be a cumulative list of totals for each team over the
#season

# %%
teams = data.HomeTeam.unique()


teamlst = {Team : [0] for Team in teams}

# %%
teamlst
# Out:
# {'Liverpool': [0],
#  'West Ham': [0],
#  'Bournemouth': [0],
#  'Burnley': [0],
#  'Crystal Palace': [0],
#  'Watford': [0],
#  'Tottenham': [0],
#  'Leicester': [0],
#  'Newcastle': [0],
#  'Man United': [0],
#  'Arsenal': [0],
#  'Aston Villa': [0],
#  'Brighton': [0],
#  'Everton': [0],
#  'Norwich': [0],
#  'Southampton': [0],
#  'Man City': [0],
#  'Sheffield United': [0],
#  'Chelsea': [0],
#  'Wolves': [0]}

# %%
#for each row in dataframe

for row in data.itertuples():
    
    #adding home and away team names to the variable
    
    
    home = row.HomeTeam
    away = row.AwayTeam
    #giving the points to the correct team after reading the games
    if row.FTHG > row.FTAG:
        teamlst[home].append(teamlst[home][-1]+3)
        teamlst[away].append(teamlst[away][-1]+0)
        
    elif row.FTHG < row.FTAG:
        teamlst[home].append(teamlst[home][-1]+0)
        teamlst[away].append(teamlst[home][-1]+3)
        
    else:
        teamlst[home].append(teamlst[home][-1]+1)
        teamlst[away].append(teamlst[home][-1]+1)

# %%
#teamlst['Wolves']

# %%
##Thats a trial

match = list(range(0, 39))

plt.plot(match, teamlst['Southampton'], color='r')
plt.plot(match, teamlst['Everton'])

# %%
## Season 2019-2020

# %%
## Watford vs bournemouth

# %%
fig, ax = plt.subplots(figsize=(12,12))



plt.plot(match, teamlst['Bournemouth'], color='r')
plt.plot(match, teamlst['Watford'], color='orange')

#setting titles

plt.xlabel('Gameweek')
plt.ylabel('Points')
plt.title('Bournemouth vs Watford')

#grid

plt.grid()
ax.xaxis.grid(color="#F8F8F8")
ax.yaxis.grid(color="#F9F9F9")

#remove margins between lines and axes

plt.margins(x=0, y=0)

#making 90° angle

ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
plt.savefig('./Figures/BournemouthvsWatford.pdf')

# %%
## Norwich Watford

# %%
fig, ax = plt.subplots(figsize=(12,12))



plt.plot(match, teamlst['Norwich'], color='green')
plt.plot(match, teamlst['Watford'], color='orange')

#setting titles

plt.xlabel('Gameweek')
plt.ylabel('Points')
plt.title('Bournemouth vs Watford')

#grid

plt.grid()
ax.xaxis.grid(color="#F8F8F8")
ax.yaxis.grid(color="#F9F9F9")

#remove margins between lines and axes

plt.margins(x=0, y=0)

#making 90° angle

ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
plt.savefig('./Figures/NorwichvsWatford.pdf')

# %%
fig, ax = plt.subplots(figsize=(12,12))



plt.plot(match, teamlst['Bournemouth'], color='r')
plt.plot(match, teamlst['Aston Villa'], color='lightblue')

#setting titles

plt.xlabel('Gameweek')
plt.ylabel('Points')
plt.title('Bournemouth vs Aston villa')

#grid

plt.grid()
ax.xaxis.grid(color="#F8F8F8")
ax.yaxis.grid(color="#F9F9F9")

#remove margins between lines and axes

plt.margins(x=0, y=0)

#making 90° angle

ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
plt.savefig('./Figures/BournemouthvsAstonvilla.pdf')

# %%
#midtable teams

# %%
fig, ax = plt.subplots(figsize=(12,12))



plt.plot(match, teamlst['West Ham'], color='lightblue')
plt.plot(match, teamlst['Newcastle'], color='black')

#setting titles

plt.xlabel('Gameweek')
plt.ylabel('Points')
plt.title('WestHam vs Newcastle')

#grid

plt.grid()
ax.xaxis.grid(color="#F8F8F8")
ax.yaxis.grid(color="#F9F9F9")

#remove margins between lines and axes

plt.margins(x=0, y=0)

#making 90° angle

ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
plt.savefig('./Figures/WestHamvsNewcastle1920.pdf')

# %%
## season 2018-2019

# %%
fig, ax = plt.subplots(figsize=(12,12))



plt.plot(match, teamlst['Huddersfield'], color='grey')
plt.plot(match, teamlst['Fulham'], color='black')

#setting titles

plt.xlabel('Gameweek')
plt.ylabel('Points')
plt.title('Fulham vs Huddersfield')

#grid

plt.grid()
ax.xaxis.grid(color="#F8F8F8")
ax.yaxis.grid(color="#F9F9F9")

#remove margins between lines and axes

plt.margins(x=0, y=0)

#making 90° angle

ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
plt.savefig('./Figures/FulhamvsHuddersfield.pdf')

# %%
fig, ax = plt.subplots(figsize=(12,12))



plt.plot(match, teamlst['Cardiff'], color='green')
plt.plot(match, teamlst['Brighton'], color='blue')

#setting titles

plt.xlabel('Gameweek')
plt.ylabel('Points')
plt.title('Cardiff vs Brighton')

#grid

plt.grid()
ax.xaxis.grid(color="#F8F8F8")
ax.yaxis.grid(color="#F9F9F9")

#remove margins between lines and axes

plt.margins(x=0, y=0)

#making 90° angle

ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
plt.savefig('./Figures/CardiffvsBrighton.pdf')

# %%
# Midtable teams

# %%
fig, ax = plt.subplots(figsize=(12,12))



plt.plot(match, teamlst['West Ham'], color='lightblue')
plt.plot(match, teamlst['Newcastle'], color='black')

#setting titles

plt.xlabel('Gameweek')
plt.ylabel('Points')
plt.title('WestHam vs Newcastle')

#grid

plt.grid()
ax.xaxis.grid(color="#F8F8F8")
ax.yaxis.grid(color="#F9F9F9")

#remove margins between lines and axes

plt.margins(x=0, y=0)

#making 90° angle

ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
plt.savefig('./Figures/WestHamvsNewcastle1819.pdf')

# %%
## 2017 - 2018

# %%
fig, ax = plt.subplots(figsize=(12,12))



plt.plot(match, teamlst['Stoke'], color='r')
plt.plot(match, teamlst['West Brom'], color='blue')

#setting titles

plt.xlabel('Gameweek')
plt.ylabel('Points')
plt.title('Stoke vs West Brom')

#grid

plt.grid()
ax.xaxis.grid(color="#F8F8F8")
ax.yaxis.grid(color="#F9F9F9")

#remove margins between lines and axes

plt.margins(x=0, y=0)

#making 90° angle

ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
plt.savefig('./Figures/StokevsWestBrom.pdf')

# %%
fig, ax = plt.subplots(figsize=(12,12))



plt.plot(match, teamlst['Stoke'], color='r')
plt.plot(match, teamlst['Swansea'], color='black')

#setting titles

plt.xlabel('Gameweek')
plt.ylabel('Points')
plt.title('Stoke vs Swansea')

#grid

plt.grid()
ax.xaxis.grid(color="#F8F8F8")
ax.yaxis.grid(color="#F9F9F9")

#remove margins between lines and axes

plt.margins(x=0, y=0)

#making 90° angle

ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
plt.savefig('./Figures/StokevsSwansea.pdf')

# %%
fig, ax = plt.subplots(figsize=(12,12))



plt.plot(match, teamlst['Southampton'], color='r')
plt.plot(match, teamlst['Swansea'], color='black')

#setting titles

plt.xlabel('Gameweek')
plt.ylabel('Points')
plt.title('Swansea vs Southhampton')

#grid

plt.grid()
ax.xaxis.grid(color="#F8F8F8")
ax.yaxis.grid(color="#F9F9F9")

#remove margins between lines and axes

plt.margins(x=0, y=0)

#making 90° angle

ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
plt.savefig('./Figures/SwanseavsSouthampton.pdf')

# %%
## midtable teams

fig, ax = plt.subplots(figsize=(12,12))



plt.plot(match, teamlst['West Ham'], color='lightblue')
plt.plot(match, teamlst['Newcastle'], color='black')

#setting titles

plt.xlabel('Gameweek')
plt.ylabel('Points')
plt.title('WestHam vs Newcastle')

#grid

plt.grid()
ax.xaxis.grid(color="#F8F8F8")
ax.yaxis.grid(color="#F9F9F9")

#remove margins between lines and axes

plt.margins(x=0, y=0)

#making 90° angle

ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
plt.savefig('./Figures/WestHamvsNewcastle1718.pdf')
