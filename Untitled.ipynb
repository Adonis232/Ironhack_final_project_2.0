# %%
import pandas as pd
import numpy as np
import glob
import matplotlib.pyplot as plt
import sys

from itertools import cycle
from collections import defaultdict
from datetime import datetime


# %matplotlib inline

# %%
pd.set_option('display.max_rows', None) #displaying all rows

# %% [markdown]
# Using glob to read all my csv files and merging them into one

# %%
path = './data/'
all_files = glob.glob(path + "*.csv")

li = []
df = []

for file in all_files:
    df = pd.read_csv(file, index_col=None, header=0)
    li.append(df)
frame = pd.concat(li, axis=0, ignore_index=True)

# %%
frame
# Out:
#      Div        Date          HomeTeam    AwayTeam  FTHG  FTAG FTR  HTHG  \
# 0     E0  18/08/2012           Arsenal  Sunderland     0     0   D     0
# 1     E0  18/08/2012            Fulham     Norwich     5     0   H     2
# 2     E0  18/08/2012         Newcastle   Tottenham     2     1   H     0
# 3     E0  18/08/2012               QPR     Swansea     0     5   A     0
# 4     E0  18/08/2012           Reading       Stoke     1     1   D     0
# ...   ..         ...               ...         ...   ...   ...  ..   ...
# 7170  E0  13/05/2007     Middlesbrough      Fulham     3     1   H     2
# 7171  E0  13/05/2007        Portsmouth     Arsenal     0     0   D     0
# 7172  E0  13/05/2007  Sheffield United       Wigan     1     2   A     1
# 7173  E0  13/05/2007         Tottenham    Man City     2     1   H     2
# 7174  E0  13/05/2007           Watford   Newcastle     1     1   D     0
#
#       HTAG HTR  ... AvgC<2.5  AHCh  B365CAHH  B365CAHA  PCAHH  PCAHA  MaxCAHH  \
# 0        0   D  ...      NaN   NaN       NaN       NaN    NaN    NaN      NaN
# 1        0   H  ...      NaN   NaN       NaN       NaN    NaN    NaN      NaN
# 2        0   D  ...      NaN   NaN       NaN       NaN    NaN    NaN      NaN
# 3        1   A  ...      NaN   NaN       NaN       NaN    NaN    NaN      NaN
# 4        1   A  ...      NaN   NaN       NaN       NaN    NaN    NaN      NaN
# ...    ...  ..  ...      ...   ...       ...       ...    ...    ...      ...
# 7170     1   H  ...      NaN   NaN       NaN       NaN    NaN    NaN      NaN
# 7171     0   D  ...      NaN   NaN       NaN       NaN    NaN    NaN      NaN
# 7172     2   A  ...      NaN   NaN       NaN       NaN    NaN    NaN      NaN
# 7173     1   H  ...      NaN   NaN       NaN       NaN    NaN    NaN      NaN
# 7174     1   A  ...      NaN   NaN       NaN       NaN    NaN    NaN      NaN
#
#       MaxCAHA  AvgCAHH  AvgCAHA
# 0         NaN      NaN      NaN
# 1         NaN      NaN      NaN
# 2         NaN      NaN      NaN
# 3         NaN      NaN      NaN
# 4         NaN      NaN      NaN
# ...       ...      ...      ...
# 7170      NaN      NaN      NaN
# 7171      NaN      NaN      NaN
# 7172      NaN      NaN      NaN
# 7173      NaN      NaN      NaN
# 7174      NaN      NaN      NaN
#
# [7175 rows x 111 columns]

# %%
frame['Date'] = pd.to_datetime(frame.Date)
a = frame.sort_values(['Date'])

# %%
a.to_csv('./data/sorteddf.csv', index=False)

# %% [markdown]
# ## Reading all matches csv

# %%
df = pd.read_csv('./data/sorteddf.csv')

r, c = df.shape
print('Dataframe has {} rows and {} columns.'.format(r,c))
# Out:
# Dataframe has 7175 rows and 111 columns.

# %%
df.head()
# Out:
#   Div        Date   HomeTeam       AwayTeam  FTHG  FTAG FTR  HTHG  HTAG HTR  \
# 0  E0  2000-08-19  Tottenham        Ipswich     3     1   H     2     1   H
# 1  E0  2000-08-19   Charlton       Man City     4     0   H     2     0   H
# 2  E0  2000-08-19    Chelsea       West Ham     4     2   H     1     0   H
# 3  E0  2000-08-19   Coventry  Middlesbrough     1     3   A     1     1   D
# 4  E0  2000-08-19      Derby    Southampton     2     2   D     1     2   A
#
#    ... AvgC<2.5  AHCh  B365CAHH  B365CAHA  PCAHH  PCAHA  MaxCAHH  MaxCAHA  \
# 0  ...      NaN   NaN       NaN       NaN    NaN    NaN      NaN      NaN
# 1  ...      NaN   NaN       NaN       NaN    NaN    NaN      NaN      NaN
# 2  ...      NaN   NaN       NaN       NaN    NaN    NaN      NaN      NaN
# 3  ...      NaN   NaN       NaN       NaN    NaN    NaN      NaN      NaN
# 4  ...      NaN   NaN       NaN       NaN    NaN    NaN      NaN      NaN
#
#    AvgCAHH  AvgCAHA
# 0      NaN      NaN
# 1      NaN      NaN
# 2      NaN      NaN
# 3      NaN      NaN
# 4      NaN      NaN
#
# [5 rows x 111 columns]

# %%
df.columns
# Out:
# Index(['Div', 'Date', 'HomeTeam', 'AwayTeam', 'FTHG', 'FTAG', 'FTR', 'HTHG',
#        'HTAG', 'HTR',
#        ...
#        'AvgC<2.5', 'AHCh', 'B365CAHH', 'B365CAHA', 'PCAHH', 'PCAHA', 'MaxCAHH',
#        'MaxCAHA', 'AvgCAHH', 'AvgCAHA'],
#       dtype='object', length=111)

# %% [markdown]
# # Data cleaning

# %%
betting_cols_drop = range(df.columns.get_loc('B365H'), df.columns.size)
df.drop(df.columns[[betting_cols_drop]], inplace=True, axis=1)
# Out:
# /home/emmanuel/miniconda3/envs/ironhack_env/lib/python3.7/site-packages/pandas/core/indexes/base.py:3940: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   result = getitem(key)

# %%
df = df.drop(['Div','Time'],axis=1)

# %%
df
# Out:
#             Date     HomeTeam          AwayTeam  FTHG  FTAG FTR  HTHG  HTAG  \
# 0     2000-08-19    Tottenham           Ipswich     3     1   H     2     1
# 1     2000-08-19     Charlton          Man City     4     0   H     2     0
# 2     2000-08-19      Chelsea          West Ham     4     2   H     1     0
# 3     2000-08-19     Coventry     Middlesbrough     1     3   A     1     1
# 4     2000-08-19        Derby       Southampton     2     2   D     1     2
# ...          ...          ...               ...   ...   ...  ..   ...   ...
# 7170  2020-07-26     Man City           Norwich     5     0   H     2     0
# 7171  2020-07-26    Newcastle         Liverpool     1     3   A     1     1
# 7172  2020-07-26  Southampton  Sheffield United     3     1   H     0     1
# 7173  2020-07-26     West Ham       Aston Villa     1     1   D     0     0
# 7174  2020-07-26      Burnley          Brighton     1     2   A     1     1
#
#      HTR        Referee  ...  AC  HY  AY  HR  AR  Attendance  HHW  AHW   HO  \
# 0      H     Alan Wiley  ...   4   0   0   0   0     36148.0  2.0  1.0  2.0
# 1      H     Rob Harris  ...   6   1   2   0   0     20043.0  2.0  1.0  8.0
# 2      H  Graham Barber  ...   7   1   2   0   0     34914.0  1.0  0.0  2.0
# 3      D   Barry Knight  ...   4   5   3   1   0     20624.0  0.0  1.0  1.0
# 4      A    Andy D'Urso  ...   8   1   1   0   0     27223.0  0.0  0.0  0.0
# ...   ..            ...  ...  ..  ..  ..  ..  ..         ...  ...  ...  ...
# 7170   H       C Pawson  ...   0   1   1   0   0         NaN  NaN  NaN  NaN
# 7171   D       A Taylor  ...   4   1   0   0   0         NaN  NaN  NaN  NaN
# 7172   A       P Bankes  ...   1   0   1   0   0         NaN  NaN  NaN  NaN
# 7173   D       M Oliver  ...   7   2   1   0   0         NaN  NaN  NaN  NaN
# 7174   D         J Moss  ...   7   3   0   0   0         NaN  NaN  NaN  NaN
#
#        AO
# 0     3.0
# 1     6.0
# 2     3.0
# 3     3.0
# 4     2.0
# ...   ...
# 7170  NaN
# 7171  NaN
# 7172  NaN
# 7173  NaN
# 7174  NaN
#
# [7175 rows x 27 columns]

# %%
df.to_csv('./data/clean_matches.csv', index=False)
df = pd.read_csv('./data/clean_matches.csv')

# %%
print('Dataframe shape: {}'.format(df.shape))
print('Column names are: {}'.format(df.columns))
df.head()
# Out:
# Dataframe shape: (7175, 27)
# Column names are: Index(['Date', 'HomeTeam', 'AwayTeam', 'FTHG', 'FTAG', 'FTR', 'HTHG', 'HTAG',
#        'HTR', 'Referee', 'HS', 'AS', 'HST', 'AST', 'HF', 'AF', 'HC', 'AC',
#        'HY', 'AY', 'HR', 'AR', 'Attendance', 'HHW', 'AHW', 'HO', 'AO'],
#       dtype='object')
#          Date   HomeTeam       AwayTeam  FTHG  FTAG FTR  HTHG  HTAG HTR  \
# 0  2000-08-19  Tottenham        Ipswich     3     1   H     2     1   H
# 1  2000-08-19   Charlton       Man City     4     0   H     2     0   H
# 2  2000-08-19    Chelsea       West Ham     4     2   H     1     0   H
# 3  2000-08-19   Coventry  Middlesbrough     1     3   A     1     1   D
# 4  2000-08-19      Derby    Southampton     2     2   D     1     2   A
#
#          Referee  ...  AC  HY  AY  HR  AR  Attendance  HHW  AHW   HO   AO
# 0     Alan Wiley  ...   4   0   0   0   0     36148.0  2.0  1.0  2.0  3.0
# 1     Rob Harris  ...   6   1   2   0   0     20043.0  2.0  1.0  8.0  6.0
# 2  Graham Barber  ...   7   1   2   0   0     34914.0  1.0  0.0  2.0  3.0
# 3   Barry Knight  ...   4   5   3   1   0     20624.0  0.0  1.0  1.0  3.0
# 4    Andy D'Urso  ...   8   1   1   0   0     27223.0  0.0  0.0  0.0  2.0
#
# [5 rows x 27 columns]

# %%
df.describe()
# Out:
#               FTHG         FTAG         HTHG         HTAG           HS  \
# count  7175.000000  7175.000000  7175.000000  7175.000000  7175.000000
# mean      1.531010     1.139373     0.681394     0.498118    13.599443
# std       1.294347     1.130502     0.830629     0.714434     5.268783
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       1.000000     0.000000     0.000000     0.000000    10.000000
# 50%       1.000000     1.000000     0.000000     0.000000    13.000000
# 75%       2.000000     2.000000     1.000000     1.000000    17.000000
# max       9.000000     9.000000     5.000000     5.000000    43.000000
#
#                 AS          HST          AST           HF           AF  ...  \
# count  7175.000000  7175.000000  7175.000000  7175.000000  7175.000000  ...
# mean     10.646132     6.277631     4.854355    11.350941    11.898537  ...
# std       4.558032     3.381985     2.841722     3.749367     3.910380  ...
# min       0.000000     0.000000     0.000000     0.000000     1.000000  ...
# 25%       7.000000     4.000000     3.000000     9.000000     9.000000  ...
# 50%      10.000000     6.000000     4.000000    11.000000    12.000000  ...
# 75%      13.000000     8.000000     6.000000    14.000000    14.000000  ...
# max      30.000000    24.000000    20.000000    33.000000    28.000000  ...
#
#                 AC           HY           AY           HR           AR  \
# count  7175.000000  7175.000000  7175.000000  7175.000000  7175.000000
# mean      4.800000     1.411986     1.758188     0.062718     0.090732
# std       2.738995     1.190531     1.272879     0.254258     0.298667
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       3.000000     0.000000     1.000000     0.000000     0.000000
# 50%       4.000000     1.000000     2.000000     0.000000     0.000000
# 75%       6.000000     2.000000     3.000000     0.000000     0.000000
# max      19.000000     7.000000     9.000000     3.000000     2.000000
#
#          Attendance         HHW         AHW          HO          AO
# count    380.000000  380.000000  380.000000  380.000000  380.000000
# mean   32911.721053    0.381579    0.223684    3.628947    3.728947
# std    12600.528803    0.640891    0.459399    2.602354    2.615703
# min    14651.000000    0.000000    0.000000    0.000000    0.000000
# 25%    22006.000000    0.000000    0.000000    2.000000    2.000000
# 50%    33199.000000    0.000000    0.000000    3.000000    3.000000
# 75%    38343.500000    1.000000    0.000000    5.000000    5.000000
# max    67637.000000    4.000000    2.000000   14.000000   17.000000
#
# [8 rows x 21 columns]

# %%
pd.set_option('display.max_columns', None)

# %% [markdown]
# ## Top historic in  a home game scorer

# %%
df[df['FTHG'] == df['FTHG'].max()]
# Out:
#             Date   HomeTeam AwayTeam  FTHG  FTAG FTR  HTHG  HTAG HTR  \
# 3123  2009-11-22  Tottenham    Wigan     9     1   H     1     0   H
#
#        Referee  ...  AC  HY  AY  HR  AR  Attendance  HHW  AHW  HO  AO
# 3123  P Walton  ...   5   1   0   0   0         NaN  NaN  NaN NaN NaN
#
# [1 rows x 27 columns]

# %% [markdown]
# ## Top historic away scorer

# %%
df[df['FTAG'] == df['FTAG'].max()]
# Out:
#             Date     HomeTeam   AwayTeam  FTHG  FTAG FTR  HTHG  HTAG HTR  \
# 6885  2019-10-25  Southampton  Leicester     0     9   A     0     5   A
#
#          Referee  ...  AC  HY  AY  HR  AR  Attendance  HHW  AHW  HO  AO
# 6885  A Marriner  ...   7   0   0   1   0         NaN  NaN  NaN NaN NaN
#
# [1 rows x 27 columns]

# %% [markdown]
# ## Top shooter in a home game

# %%
df[df['HS'] == df['HS'].max()]
# Out:
#             Date  HomeTeam   AwayTeam  FTHG  FTAG FTR  HTHG  HTAG HTR  \
# 5185  2015-03-21  Man City  West Brom     3     0   H     2     0   H
#
#           Referee  HS  AS  HST  AST  HF  AF  HC  AC  HY  AY  HR  AR  \
# 5185  N Swarbrick  43   3   16    0   6   5   9   2   0   0   0   1
#
#       Attendance  HHW  AHW  HO  AO
# 5185         NaN  NaN  NaN NaN NaN

# %% [markdown]
# It was Man city with 43 shots and 16 on target for 3 shots for west bromwich
# but 0 on target, we can see that even being shot at so many times, if we see
# at the foults made by each team we can see that they are almost the same but they
# lost a player due to a red card.

# %% [markdown]
# ## Top shooter with no sent-offs

# %%
#getting the matches with no red cards in it 

df_no_red = df[(df['HR'] == 0) & (df['AR'] == 0)]
df_no_red.shape
# Out:
# (6182, 27)

# %%
df_no_red[df_no_red['HS'] == df_no_red['HS'].max()]
# Out:
#             Date HomeTeam  AwayTeam  FTHG  FTAG FTR  HTHG  HTAG HTR  \
# 4742  2014-01-29  Chelsea  West Ham     0     0   D     0     0   D
#
#           Referee  HS  AS  HST  AST  HF  AF  HC  AC  HY  AY  HR  AR  \
# 4742  N Swarbrick  39   1    9    1  12  11  13   3   1   3   0   0
#
#       Attendance  HHW  AHW  HO  AO
# 4742         NaN  NaN  NaN NaN NaN

# %% [markdown]
# Again the home team has clearly more shots than the away team
# 39 Chelsea for just 1 for West Ham. Without a red card Chelse was the best shooter

# %%
#Away tema with most shots in a match

# %%
df[df['AS'] == df['AS'].max()]
# Out:
#             Date HomeTeam AwayTeam  FTHG  FTAG FTR  HTHG  HTAG HTR   Referee  \
# 4179  2012-09-22  Swansea  Everton     0     3   A     0     2   A  A Taylor
# 6123  2017-10-22  Everton  Arsenal     2     5   A     1     1   D  C Pawson
#
#       HS  AS  HST  AST  HF  AF  HC  AC  HY  AY  HR  AR  Attendance  HHW  AHW  \
# 4179  18  30   11   19  23   7   8   3   4   1   1   0         NaN  NaN  NaN
# 6123   8  30    3   14  14  14   0   7   1   1   1   0         NaN  NaN  NaN
#
#       HO  AO
# 4179 NaN NaN
# 6123 NaN NaN

# %% [markdown]
# We have 2 (Arsenal and Everton) teams, one is shooting way more than the other, each having 30 shots
# for 18 and 8 fro the home team, but can see that eficiency for Arsenal could be better.

# %% [markdown]
# # Wich team has scored more goals and wich had most shots(overall)??

# %%
#Building a new dataframe giving the total goals and shots for each team


team_goal = defaultdict(int)
team_shot = defaultdict(int)
team_goal_diff = defaultdict(int)
team_goals_shots = {}



for HomeTeam, AwayTeam, FTHG, FTAG, HS, AS in df[['HomeTeam', 'AwayTeam', 'FTHG', 'FTAG', 'HS', 'AS']].values:
    team_goal[HomeTeam] += FTHG
    team_goal[AwayTeam] += FTAG
    team_shot[HomeTeam] += HS
    team_shot[AwayTeam] += AS
    team_goal_diff[HomeTeam] += (FTHG - FTAG)
    team_goal_diff[AwayTeam] += (FTAG - FTHG)

df_team_goals = pd.DataFrame(team_goal.items(), columns=['Team', 'Goals'])
df_team_shot = pd.DataFrame(team_shot.items(), columns=['Team', 'Shots'])
team_goal_diff = pd.DataFrame(team_goal_diff.items(), columns= ['Team', 'GoalDiff'])

# %%
#Higher scorers
df_team_goals.head()
# Out:
#          Team  Goals
# 0     Arsenal   1352
# 1  Man United   1335
# 2     Chelsea   1328
# 3    Man City   1291
# 4   Liverpool   1283

# %%
df_team_goals.sort_values(by=['Goals'], ascending=False, inplace=True)
df_team_goals.reset_index(inplace=True, drop=True)

# %%
df_team_goals.head()
# Out:
#          Team  Goals
# 0     Arsenal   1352
# 1  Man United   1335
# 2     Chelsea   1328
# 3    Man City   1291
# 4   Liverpool   1283

# %% [markdown]
# Man. City it is 3rd top historical scorer wich is remarcable since Man city
# has been only on the top not as long as other top scorers.

# %% [markdown]
# ## Least scorers

# %%
df_team_goals.tail()
# Out:
#             Team  Goals
# 38       Ipswich     57
# 39     Blackpool     55
# 40  Huddersfield     50
# 41      Coventry     36
# 42      Bradford     30

# %% [markdown]
# None of these teams are still on EPL so these numbers dont tell the whole
# truth since some of them have only been for a couple of seasons on the
# league

# %% [markdown]
# ## Top shooters

# %%
df_team_shot.sort_values(by='Shots', ascending=False, inplace=True)
df_team_shot.reset_index(inplace=True, drop=True)
df_team_shot.head()
# Out:
#          Team  Shots
# 0   Liverpool  10951
# 1     Chelsea  10842
# 2  Man United  10425
# 3    Man City  10256
# 4     Arsenal  10036

# %% [markdown]
# We can see that obviously the same teams are top scorers and top shooters

# %%
df_team_shot.tail()
# Out:
#          Team  Shots
# 38      Derby    640
# 39    Ipswich    491
# 40  Blackpool    446
# 41   Coventry    389
# 42   Bradford    371

# %% [markdown]
# Teams not in the league again.

# %% [markdown]
# # Shots per goal made

# %%
df_team_goals_shots = df_team_goals.copy()
df_team_goals_shots = df_team_goals_shots.merge(df_team_shot)
df_team_goals_shots['Shots_per_goal'] = (df_team_goals_shots['Shots']/df_team_goals_shots['Goals'].round(2))
df_team_goals_shots.sort_values(by='Shots_per_goal', inplace=True)
df_team_goals_shots.reset_index(inplace=True, drop=True)
df_team_goals_shots
# Out:
#                 Team  Goals  Shots  Shots_per_goal
# 0            Arsenal   1352  10036        7.423077
# 1              Leeds    162   1250        7.716049
# 2         Man United   1335  10425        7.808989
# 3            Reading    136   1073        7.889706
# 4           Man City   1291  10256        7.944229
# 5          Blackpool     55    446        8.109091
# 6           Charlton    261   2121        8.126437
# 7            Chelsea   1328  10842        8.164157
# 8          Leicester    423   3578        8.458629
# 9          Liverpool   1283  10951        8.535464
# 10           Ipswich     57    491        8.614035
# 11         Tottenham   1132   9890        8.736749
# 12        Birmingham    268   2379        8.876866
# 13           Everton    962   8623        8.963617
# 14         Blackburn    460   4148        9.017391
# 15       Bournemouth    241   2211        9.174274
# 16       Aston Villa    709   6565        9.259520
# 17            Fulham    555   5242        9.445045
# 18          West Ham    738   7031        9.527100
# 19         Newcastle    774   7426        9.594315
# 20     Middlesbrough    372   3578        9.618280
# 21           Swansea    306   2964        9.686275
# 22             Stoke    398   3881        9.751256
# 23            Bolton    446   4370        9.798206
# 24            Wolves    254   2490        9.803150
# 25           Burnley    233   2351       10.090129
# 26       Southampton    554   5679       10.250903
# 27    Crystal Palace    332   3404       10.253012
# 28           Watford    241   2506       10.398340
# 29        Portsmouth    287   3014       10.501742
# 30         West Brom    471   4980       10.573248
# 31  Sheffield United     71    756       10.647887
# 32        Sunderland    491   5256       10.704684
# 33          Coventry     36    389       10.805556
# 34           Norwich    223   2462       11.040359
# 35              Hull    181   2002       11.060773
# 36          Brighton    108   1209       11.194444
# 37             Derby     57    640       11.228070
# 38             Wigan    316   3588       11.354430
# 39          Bradford     30    371       12.366667
# 40           Cardiff     66    836       12.666667
# 41               QPR    115   1492       12.973913
# 42      Huddersfield     50    760       15.200000

# %% [markdown]
# We can see that accuracy on the attack it is obvious on the top teams
# some of these dta it is not accurate because Reading and Leeds are up there
# but they are every year playing in the league

# %% [markdown]
# # Goal difference

# %%
team_goal_diff.sort_values(by='GoalDiff', ascending=False, inplace=True)
team_goal_diff.reset_index(inplace=True, drop=True)
team_goal_diff
# Out:
#                 Team  GoalDiff
# 0         Man United       705
# 1            Chelsea       681
# 2            Arsenal       602
# 3          Liverpool       579
# 4           Man City       505
# 5          Tottenham       262
# 6            Everton        87
# 7            Ipswich        15
# 8          Leicester         4
# 9              Leeds       -17
# 10         Blackpool       -23
# 11  Sheffield United       -23
# 12          Coventry       -27
# 13          Bradford       -40
# 14       Southampton       -49
# 15           Reading       -50
# 16          Brighton       -60
# 17          Charlton       -68
# 18         Blackburn       -75
# 19           Cardiff       -77
# 20           Swansea       -77
# 21     Middlesbrough       -82
# 22      Huddersfield       -84
# 23               QPR       -84
# 24        Portsmouth       -87
# 25        Birmingham       -88
# 26       Bournemouth       -89
# 27             Derby       -91
# 28    Crystal Palace       -97
# 29            Bolton       -99
# 30            Wolves      -113
# 31           Burnley      -114
# 32           Watford      -123
# 33             Stoke      -127
# 34              Hull      -142
# 35       Aston Villa      -143
# 36         Newcastle      -144
# 37             Wigan      -166
# 38          West Ham      -167
# 39           Norwich      -172
# 40            Fulham      -172
# 41         West Brom      -217
# 42        Sunderland      -253

# %% [markdown]
# Most of the teams are in negative numbers only 8 out of 42 have positive numbers
# on the goal difference.

# %% [markdown]
# # Looking who is refereeing

# %% [markdown]
# most red cards

# %%
df_ref_red = df[['Referee', 'HR', 'AR']].groupby(df['Referee']).sum()
df_ref_red.head()
# Out:
#             HR  AR
# Referee
# A D'Urso     5   5
# A Madley     1   0
# A Marriner  20  36
# A Taylor    20  16
# A Wiley      8  20

# %% [markdown]
# This is historical so it is of no use for us since nost of these referees are not active
# we have to select only the active ones so I'm going to pick he ones from last seasons.

# %%
#I chose referees fro the last 4 seasons

df_act_ref = df.loc[df['Date'] >='2016']
df_act_ref.head()
# Out:
#             Date    HomeTeam     AwayTeam  FTHG  FTAG FTR  HTHG  HTAG HTR  \
# 5465  2016-01-02    West Ham    Liverpool     2     0   H     1     0   H
# 5466  2016-01-02  Sunderland  Aston Villa     3     1   H     1     0   H
# 5467  2016-01-02     Watford     Man City     1     2   A     0     0   D
# 5468  2016-01-02     Arsenal    Newcastle     1     0   H     0     0   D
# 5469  2016-01-02   Leicester  Bournemouth     0     0   D     0     0   D
#
#          Referee  ...  AC  HY  AY  HR  AR  Attendance  HHW  AHW  HO  AO
# 5465    R Madley  ...   9   1   1   0   0         NaN  NaN  NaN NaN NaN
# 5466    C Pawson  ...   3   3   4   0   0         NaN  NaN  NaN NaN NaN
# 5467  M Atkinson  ...   5   1   0   0   0         NaN  NaN  NaN NaN NaN
# 5468    A Taylor  ...   4   2   2   0   0         NaN  NaN  NaN NaN NaN
# 5469  A Marriner  ...   1   1   1   0   1         NaN  NaN  NaN NaN NaN
#
# [5 rows x 27 columns]

# %%
df_act_ref_red = df_act_ref[['Referee', 'HR', 'AR']].groupby(df['Referee']).sum()
print(df_act_ref_red.head(),'\n',
      'Dataframe shape:',df_act_ref_red.shape)
# Out:
#             HR  AR
# Referee
# A Madley     1   0
# A Marriner   5   8
# A Taylor    10   4
# C Kavanagh   2   3
# C Pawson     6  12
#  Dataframe shape: (29, 2)

# %%
df_act_ref_red['TotalReds'] = df_act_ref_red['HR'] + df_act_ref_red['AR']
df_act_ref_red.sort_values(by='TotalReds', ascending=False, inplace=True)
df_act_ref_red.reset_index(inplace=True)
df_act_ref_red.head(10)
# Out:
#    level_0  index     Referee  HR  AR  TotalReds
# 0        0      0      M Dean   7  18         25
# 1        1      1    C Pawson   6  12         18
# 2        2      2    M Oliver   7  10         17
# 3        3      3  M Atkinson   5  10         15
# 4        4      4      J Moss   9   6         15
# 5        5      5    A Taylor  10   4         14
# 6        6      6  A Marriner   5   8         13
# 7        7      7     G Scott   6   5         11
# 8        8      8    K Friend   6   3          9
# 9        9      9     L Mason   4   5          9

# %%
print(f"Mean red cards for away teams:{df_act_ref_red['AR'].mean()}")
print(f"Mean red cards for home teams:{df_act_ref_red['HR'].mean()}")
# Out:
# Mean red cards for away teams:3.8620689655172415
# Mean red cards for home teams:3.0689655172413794

# %% [markdown]
# We can see wich referees are more prone to show red cards, and we can see
# that most of them tend to show them to visitors almost a point

# %%
# Teams with more sent-offs by M Dean and Pawson

df[['HomeTeam', 'AwayTeam', 'Referee', 'HR', 'AR']][(df['Referee'] == 'M Dean') & ((df['HR'] > 0) | 
                                                                                   (df['AR'] > 0))]
# Out:
#          HomeTeam     AwayTeam Referee  HR  AR
# 448     Tottenham  Southampton  M Dean   0   1
# 467      Man City    Blackburn  M Dean   1   0
# 534        Bolton      Chelsea  M Dean   0   1
# 554   Aston Villa    West Brom  M Dean   1   0
# 618       Arsenal     West Ham  M Dean   0   1
# ...           ...          ...     ...  ..  ..
# 6730       Wolves   Man United  M Dean   0   1
# 6828  Southampton   Man United  M Dean   1   0
# 6844  Aston Villa     West Ham  M Dean   0   1
# 7044    Tottenham     Man City  M Dean   0   1
# 7048       Wolves    Leicester  M Dean   0   1
#
# [86 rows x 5 columns]

# %%
df[['HomeTeam', 'AwayTeam', 'Referee', 'HR', 'AR']][(df['Referee'] == 'C Pawson') & 
                                                    ((df['HR'] > 0) | (df['AR'] > 0))]#.groupby(['HomeTeam'])
# Out:
#             HomeTeam     AwayTeam   Referee  HR  AR
# 4968  Crystal Palace      Chelsea  C Pawson   1   1
# 5013            Hull    Tottenham  C Pawson   1   0
# 5042     Aston Villa    Leicester  C Pawson   0   1
# 5097      Sunderland    Liverpool  C Pawson   1   0
# 5141     Southampton     West Ham  C Pawson   0   1
# 5239         Swansea        Stoke  C Pawson   0   1
# 5383     Southampton  Bournemouth  C Pawson   1   0
# 5514         Everton    Newcastle  C Pawson   0   1
# 5674        West Ham  Bournemouth  C Pawson   0   1
# 5818           Stoke    Leicester  C Pawson   0   1
# 5910         Watford     West Ham  C Pawson   0   1
# 5966      Sunderland   Man United  C Pawson   1   0
# 6040         Chelsea      Burnley  C Pawson   2   0
# 6123         Everton      Arsenal  C Pawson   1   0
# 6164    Huddersfield     Man City  C Pawson   1   0
# 6421          Wolves      Everton  C Pawson   0   1
# 6426         Cardiff    Newcastle  C Pawson   0   1
# 6457     Bournemouth    Leicester  C Pawson   0   1
# 6634        Man City       Wolves  C Pawson   0   1
# 6749         Watford      Arsenal  C Pawson   1   0
# 6780     Bournemouth    Tottenham  C Pawson   0   2
# 6863       Leicester    Newcastle  C Pawson   0   1
# 7037         Watford      Everton  C Pawson   0   1

# %% [markdown]
# ## Average goals per game

# %%
games = len(df)
goals = df['FTHG'].sum() + df['FTAG'].sum()
goals_per_game = goals / games
print('Average goals per game in the league: {:.2}'.format(goals_per_game))
# Out:
# Average goals per game in the league: 2.7

# %% [markdown]
# # Goals in the first half

# %%
goals_f_h = df['HTHG'].sum() + df['HTAG'].sum()
total_g_per_fh = goals_f_h/games
print('Avg. number of goals per first half {:.2}'.format(total_g_per_fh))
# Out:
# Avg. number of goals per first half 1.2

# %% [markdown]
# # Goals in second half

# %%
goals_s_h = goals - goals_f_h
goals_per_s_h = goals_s_h/games
print('Avg. of goals in secong half {:.2}'.format(goals_per_s_h))
# Out:
# Avg. of goals in secong half 1.5

# %% [markdown]
# It is more likely to see goals in the second half than in the first one,
# can be due to low stamina, would be nice to see when is it that it starts really
# to tend to score(minute of the game)

# %% [markdown]
#  ## Getting the most and least common scores

# %%
# Adding a new columns with the results of the game

# %%
df['Score'] = df['FTHG'].map(str) + ':' + df['FTAG'].map(str)
df.head()
# Out:
#          Date   HomeTeam       AwayTeam  FTHG  FTAG FTR  HTHG  HTAG HTR  \
# 0  2000-08-19  Tottenham        Ipswich     3     1   H     2     1   H
# 1  2000-08-19   Charlton       Man City     4     0   H     2     0   H
# 2  2000-08-19    Chelsea       West Ham     4     2   H     1     0   H
# 3  2000-08-19   Coventry  Middlesbrough     1     3   A     1     1   D
# 4  2000-08-19      Derby    Southampton     2     2   D     1     2   A
#
#          Referee  ...  HY  AY  HR  AR  Attendance  HHW  AHW   HO   AO  Score
# 0     Alan Wiley  ...   0   0   0   0     36148.0  2.0  1.0  2.0  3.0    3:1
# 1     Rob Harris  ...   1   2   0   0     20043.0  2.0  1.0  8.0  6.0    4:0
# 2  Graham Barber  ...   1   2   0   0     34914.0  1.0  0.0  2.0  3.0    4:2
# 3   Barry Knight  ...   5   3   1   0     20624.0  0.0  1.0  1.0  3.0    1:3
# 4    Andy D'Urso  ...   1   1   0   0     27223.0  0.0  0.0  0.0  2.0    2:2
#
# [5 rows x 28 columns]

# %%
score = pd.DataFrame(df['Score'].groupby(df['Score']).count())
score.columns = ['Count']
score.sort_values(by='Count', inplace=True, ascending=False)

full_score = score['Score'].sum()
score['Count%'] = (100*(score['Count']/full_score)).round(2)

print('Most common score:')
print(score.head())
print('\nleast common scores:')
print(score.tail())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/miniconda3/envs/ironhack_env/lib/python3.7/site-packages/pandas/core/ops/array_ops.py in na_arithmetic_op(left, right, op, str_rep)
#     148     try:
# --> 149         result = expressions.evaluate(op, str_rep, left, right)
#     150     except TypeError:
#
# ~/miniconda3/envs/ironhack_env/lib/python3.7/site-packages/pandas/core/computation/expressions.py in evaluate(op, op_str, a, b, use_numexpr)
#     207     if use_numexpr:
# --> 208         return _evaluate(op, op_str, a, b)
#     209     return _evaluate_standard(op, op_str, a, b)
#
# ~/miniconda3/envs/ironhack_env/lib/python3.7/site-packages/pandas/core/computation/expressions.py in _evaluate_standard(op, op_str, a, b)
#      69     with np.errstate(all="ignore"):
# ---> 70         return op(a, b)
#      71
#
# TypeError: ufunc 'true_divide' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-83-c4b4bdc7b46e> in <module>
#       4
#       5 full_score = df['Score'].sum()
# ----> 6 score['Count%'] = (100*(score['Count']/full_score)).round(2)
#       7
#       8 print('Most common score:')
#
# ~/miniconda3/envs/ironhack_env/lib/python3.7/site-packages/pandas/core/ops/common.py in new_method(self, other)
#      62         other = item_from_zerodim(other)
#      63
# ---> 64         return method(self, other)
#      65
#      66     return new_method
#
# ~/miniconda3/envs/ironhack_env/lib/python3.7/site-packages/pandas/core/ops/__init__.py in wrapper(left, right)
#     501         lvalues = extract_array(left, extract_numpy=True)
#     502         rvalues = extract_array(right, extract_numpy=True)
# --> 503         result = arithmetic_op(lvalues, rvalues, op, str_rep)
#     504
#     505         return _construct_result(left, result, index=left.index, name=res_name)
#
# ~/miniconda3/envs/ironhack_env/lib/python3.7/site-packages/pandas/core/ops/array_ops.py in arithmetic_op(left, right, op, str_rep)
#     195     else:
#     196         with np.errstate(all="ignore"):
# --> 197             res_values = na_arithmetic_op(lvalues, rvalues, op, str_rep)
#     198
#     199     return res_values
#
# ~/miniconda3/envs/ironhack_env/lib/python3.7/site-packages/pandas/core/ops/array_ops.py in na_arithmetic_op(left, right, op, str_rep)
#     149         result = expressions.evaluate(op, str_rep, left, right)
#     150     except TypeError:
# --> 151         result = masked_arith_op(left, right, op)
#     152
#     153     return missing.dispatch_fill_zeros(op, left, right, result)
#
# ~/miniconda3/envs/ironhack_env/lib/python3.7/site-packages/pandas/core/ops/array_ops.py in masked_arith_op(x, y, op)
#     110         if mask.any():
#     111             with np.errstate(all="ignore"):
# --> 112                 result[mask] = op(xrav[mask], y)
#     113
#     114     result, _ = maybe_upcast_putmask(result, ~mask, np.nan)
#
# TypeError: ufunc 'true_divide' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
